# %% [markdown]
# # Get Started
# ## Install python package
# You can install `python-okx` from PyPi server.

# %%
! pip install python-okx --upgrade
# Out:
# Requirement already satisfied: python-okx in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (0.3.5)
# Requirement already satisfied: importlib-metadata in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (8.6.1)
# Requirement already satisfied: httpx[http2] in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (0.28.1)
# Requirement already satisfied: keyring in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (25.6.0)
# Requirement already satisfied: loguru in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (0.7.3)
# Requirement already satisfied: requests in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (2.32.3)
# Requirement already satisfied: Twisted in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (24.11.0)
# Requirement already satisfied: pyOpenSSL in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from python-okx) (25.0.0)
# Requirement already satisfied: anyio in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpx[http2]->python-okx) (4.8.0)
# Requirement already satisfied: certifi in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpx[http2]->python-okx) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpx[http2]->python-okx) (1.0.7)
# Requirement already satisfied: idna in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpx[http2]->python-okx) (3.10)
# Requirement already satisfied: h2<5,>=3 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpx[http2]->python-okx) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from httpcore==1.*->httpx[http2]->python-okx) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from importlib-metadata->python-okx) (3.21.0)
# Requirement already satisfied: jaraco.classes in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from keyring->python-okx) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from keyring->python-okx) (4.1.0)
# Requirement already satisfied: jaraco.context in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from keyring->python-okx) (6.0.1)
# Requirement already satisfied: cryptography<45,>=41.0.5 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from pyOpenSSL->python-okx) (44.0.0)
# Requirement already satisfied: typing-extensions>=4.9 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from pyOpenSSL->python-okx) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from requests->python-okx) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from requests->python-okx) (2.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (25.1.0)
# Requirement already satisfied: automat>=24.8.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (24.7.2)
# Requirement already satisfied: zope-interface>=5 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from Twisted->python-okx) (7.2)
# Requirement already satisfied: cffi>=1.12 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from cryptography<45,>=41.0.5->pyOpenSSL->python-okx) (1.17.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]->python-okx) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]->python-okx) (4.1.0)
# Requirement already satisfied: setuptools>=61.0 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from incremental>=24.7.0->Twisted->python-okx) (75.1.0)
# Requirement already satisfied: tomli in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from incremental>=24.7.0->Twisted->python-okx) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from anyio->httpx[http2]->python-okx) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from anyio->httpx[http2]->python-okx) (1.3.1)
# Requirement already satisfied: more-itertools in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from jaraco.classes->keyring->python-okx) (10.6.0)
# Requirement already satisfied: backports.tarfile in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from jaraco.context->keyring->python-okx) (1.2.0)
# Requirement already satisfied: pycparser in /Users/wang/anaconda3/envs/OKX/lib/python3.10/site-packages (from cffi>=1.12->cryptography<45,>=41.0.5->pyOpenSSL->python-okx) (2.22)

# %% [markdown]
# ## Sign up as an OKX user
# Please refer to [Create account](https://www.okx.com/account/register)

# %% [markdown]
# ## Create API Key
# Please refer to [Create API Key](https://www.okx.com/account/my-api)

# %% [markdown]
# ## Import API modules
# The following modules are available
# - Trade
# - BlockTrading
# - Funding
# - Account
# - Convert
# - Earning
# - SubAccount
# - MarketData
# - PublicData
# - TradingData
# - Status
# - NDBroker
# - FDBroker

# %%
import okx.Trade as Trade

# %% [markdown]
# ## Fill in your API key details

# %%
api_key = "7e557e94-1f0f-41e1-9974-347d25487c8f"
secret_key = "D92C7D9E1B12E6D7322C36AC7DC13144"
passphrase = "Wwh199807!"

# %% [markdown]
# ## Get available funds

# %%
import okx.Funding as Funding

flag = "1"  # live trading: 0, demo trading: 1

fundingAPI = Funding.FundingAPI(api_key, secret_key, passphrase, False, flag)

result = fundingAPI.get_currencies()
print(result)
# Out:
# {'code': '50038', 'data': [], 'msg': 'This feature is unavailable in demo trading'}

# %% [markdown]
# ## Get market data

# %%
import okx.MarketData as MarketData

flag = "1"  # live trading: 0, demo trading: 1

marketDataAPI = MarketData.MarketAPI(flag=flag)

result = marketDataAPI.get_tickers(instType="SPOT")
print(result)
# Out:
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': 'BOME-USDC', 'last': '0.005', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.005', 'high24h': '0.005', 'low24h': '0.005', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806687010', 'sodUtc0': '0.005', 'sodUtc8': '0.005'}, {'instType': 'SPOT', 'instId': 'OAS-USDT', 'last': '0.02894', 'lastSz': '1736834.3', 'askPx': '0.02893', 'askSz': '2338419.21', 'bidPx': '0.02886', 'bidSz': '2358820.14', 'open24h': '0.02845', 'high24h': '0.02905', 'low24h': '0.02845', 'volCcy24h': '1151111.8891534', 'vol24h': '39862275.94', 'ts': '1737806680105', 'sodUtc0': '0.02875', 'sodUtc8': '0.02874'}, {'instType': 'SPOT', 'instId': 'LINK-BTC', 'last': '0.0001762', 'lastSz': '4583.14', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.0001762', 'high24h': '0.0001762', 'low24h': '0.0001762', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806644005', 'sodUtc0': '0.0001762', 'sodUtc8': '0.0001762'}, {'instType': 'SPOT', 'instId': 'KNC-USDT', 'last': '0.5277', 'lastSz': '46562.675506', 'askPx': '0.526', 'askSz': '38695.651736', 'bidPx': '0.5254', 'bidSz': '54373.064965', 'open24h': '0.5396', 'high24h': '0.5414', 'low24h': '0.5127', 'volCcy24h': '1075697.6897751', 'vol24h': '2038601.910919', 'ts': '1737806682010', 'sodUtc0': '0.5132', 'sodUtc8': '0.5333'}, {'instType': 'SPOT', 'instId': 'IOTA-USDC', 'last': '0.1302', 'lastSz': '4.123223', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1302', 'high24h': '0.1302', 'low24h': '0.1302', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806687008', 'sodUtc0': '0.1302', 'sodUtc8': '0.1302'}, {'instType': 'SPOT', 'instId': 'MASK-ETH', 'last': '0.1', 'lastSz': '82.3726', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1', 'high24h': '0.1', 'low24h': '0.1', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806671007', 'sodUtc0': '0.1', 'sodUtc8': '0.1'}, {'instType': 'SPOT', 'instId': 'MDT-USDC', 'last': '0.02', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.02', 'high24h': '0.02', 'low24h': '0.02', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806687009', 'sodUtc0': '0.02', 'sodUtc8': '0.02'}, {'instType': 'SPOT', 'instId': 'AXS-HKD', 'last': '50', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '50', 'high24h': '50', 'low24h': '50', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806637008', 'sodUtc0': '50', 'sodUtc8': '50'}, {'instType': 'SPOT', 'instId': 'BOME-USDT', 'last': '0.012467', 'lastSz': '573', 'askPx': '0.012625', 'askSz': '5108', 'bidPx': '0.012467', 'bidSz': '244851', 'open24h': '0.012467', 'high24h': '0.012467', 'low24h': '0.012467', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806640019', 'sodUtc0': '0.012467', 'sodUtc8': '0.012467'}, {'instType': 'SPOT', 'instId': 'LUNA-USDT', 'last': '0.3396', 'lastSz': '208.537715', 'askPx': '0.3387', 'askSz': '152681.599426', 'bidPx': '0.3385', 'bidSz': '202080.372724', 'open24h': '0.3531', 'high24h': '0.3542', 'low24h': '0.332', 'volCcy24h': '9478025.6913792926', 'vol24h': '27699590.998845', 'ts': '1737806688205', 'sodUtc0': '0.3362', 'sodUtc8': '0.3495'}, {'instType': 'SPOT', 'instId': 'XEM-ETH', 'last': '0.0000361', 'lastSz': '468.527', 'askPx': '', 'askSz': '0', 'bidPx': '0.0000361', 'bidSz': '71526.59', 'open24h': '0.0000361', 'high24h': '0.0000361', 'low24h': '0.0000361', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806664010', 'sodUtc0': '0.0000361', 'sodUtc8': '0.0000361'}, {'instType': 'SPOT', 'instId': 'MEME-BTC', 'last': '0.5', 'lastSz': '100', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.5', 'high24h': '0.5', 'low24h': '0.5', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806663005', 'sodUtc0': '0.5', 'sodUtc8': '0.5'}, {'instType': 'SPOT', 'instId': 'GAS-USDC', 'last': '4.86', 'lastSz': '11.765', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '4.86', 'high24h': '4.86', 'low24h': '4.86', 'volCcy24h': '0', 'vol24h':  ...

# %% [markdown]
# ## Handle errors

# %% [markdown]
# You will the error code `51000` when. you run the following code. More details about the error code can be found in `msg`.
# Please refer to  [error code](https://www.okx.com/docs-v5/en/#error-code) for addtional information.

# %%
import okx.MarketData as MarketData

flag = "1"  # live trading: 0, demo trading: 1

marketDataAPI = MarketData.MarketAPI(flag=flag)

result = marketDataAPI.get_tickers( instType="SPOT")
print(result)
# Out:
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': 'BOME-USDC', 'last': '0.005', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.005', 'high24h': '0.005', 'low24h': '0.005', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806566010', 'sodUtc0': '0.005', 'sodUtc8': '0.005'}, {'instType': 'SPOT', 'instId': 'OAS-USDT', 'last': '0.02894', 'lastSz': '1736834.3', 'askPx': '0.02893', 'askSz': '2338419.21', 'bidPx': '0.02886', 'bidSz': '1965756.47', 'open24h': '0.02845', 'high24h': '0.02905', 'low24h': '0.02845', 'volCcy24h': '1151111.8891534', 'vol24h': '39862275.94', 'ts': '1737806583166', 'sodUtc0': '0.02875', 'sodUtc8': '0.02874'}, {'instType': 'SPOT', 'instId': 'LINK-BTC', 'last': '0.0001762', 'lastSz': '4583.14', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.0001762', 'high24h': '0.0001762', 'low24h': '0.0001762', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806583166', 'sodUtc0': '0.0001762', 'sodUtc8': '0.0001762'}, {'instType': 'SPOT', 'instId': 'KNC-USDT', 'last': '0.5277', 'lastSz': '46562.675506', 'askPx': '0.5265', 'askSz': '53892.86034', 'bidPx': '0.526', 'bidSz': '50132.327897', 'open24h': '0.5396', 'high24h': '0.5414', 'low24h': '0.5127', 'volCcy24h': '1075697.6897751', 'vol24h': '2038601.910919', 'ts': '1737806614010', 'sodUtc0': '0.5132', 'sodUtc8': '0.5333'}, {'instType': 'SPOT', 'instId': 'IOTA-USDC', 'last': '0.1302', 'lastSz': '4.123223', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1302', 'high24h': '0.1302', 'low24h': '0.1302', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806580009', 'sodUtc0': '0.1302', 'sodUtc8': '0.1302'}, {'instType': 'SPOT', 'instId': 'MASK-ETH', 'last': '0.1', 'lastSz': '82.3726', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1', 'high24h': '0.1', 'low24h': '0.1', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806610008', 'sodUtc0': '0.1', 'sodUtc8': '0.1'}, {'instType': 'SPOT', 'instId': 'MDT-USDC', 'last': '0.02', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.02', 'high24h': '0.02', 'low24h': '0.02', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806565010', 'sodUtc0': '0.02', 'sodUtc8': '0.02'}, {'instType': 'SPOT', 'instId': 'AXS-HKD', 'last': '50', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '50', 'high24h': '50', 'low24h': '50', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806576009', 'sodUtc0': '50', 'sodUtc8': '50'}, {'instType': 'SPOT', 'instId': 'BOME-USDT', 'last': '0.012467', 'lastSz': '573', 'askPx': '0.012625', 'askSz': '5108', 'bidPx': '0.012467', 'bidSz': '244851', 'open24h': '0.012467', 'high24h': '0.012467', 'low24h': '0.012467', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806580018', 'sodUtc0': '0.012467', 'sodUtc8': '0.012467'}, {'instType': 'SPOT', 'instId': 'LUNA-USDT', 'last': '0.3396', 'lastSz': '208.537715', 'askPx': '0.3391', 'askSz': '195091.33137', 'bidPx': '0.3388', 'bidSz': '156710.511787', 'open24h': '0.3531', 'high24h': '0.3542', 'low24h': '0.332', 'volCcy24h': '9478025.6913792926', 'vol24h': '27699590.998845', 'ts': '1737806615904', 'sodUtc0': '0.3362', 'sodUtc8': '0.3495'}, {'instType': 'SPOT', 'instId': 'XEM-ETH', 'last': '0.0000361', 'lastSz': '468.527', 'askPx': '', 'askSz': '0', 'bidPx': '0.0000361', 'bidSz': '71526.59', 'open24h': '0.0000361', 'high24h': '0.0000361', 'low24h': '0.0000361', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806603010', 'sodUtc0': '0.0000361', 'sodUtc8': '0.0000361'}, {'instType': 'SPOT', 'instId': 'MEME-BTC', 'last': '0.5', 'lastSz': '100', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.5', 'high24h': '0.5', 'low24h': '0.5', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1737806602006', 'sodUtc0': '0.5', 'sodUtc8': '0.5'}, {'instType': 'SPOT', 'instId': 'GAS-USDC', 'last': '4.86', 'lastSz': '11.765', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '4.86', 'high24h': '4.86', 'low24h': '4.86', 'volCcy24h': '0', 'vol24h': '0 ...

# %% [markdown]
# # Prepare for trading
# - Make sure you understand the basic trading rules. Please refer to [Basic Trading Rules](https://www.okx.com/support/hc/en-us/sections/360011507312)
# - Make sure you have enough funds in your trading account。Please refer to  [Get balance](https://www.okx.com/docs-v5/en/#rest-api-account-get-balance).

# %% [markdown]
# ## Get account balance. Please refer to  [Get balance](https://www.okx.com/docs-v5/en/#rest-api-account-get-balance).

# %%
import okx.Account as Account
flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_account_balance()
print(result)

# %% [markdown]
# ## Get available trading pairs from [Get instruments](https://www.okx.com/docs-v5/en/#rest-api-public-data-get-instruments).

# %%
import okx.PublicData as PublicData

flag = "1"  # live trading: 0, demo trading: 1

PublicDataAPI = PublicData.PublicAPI(flag=flag)

result = PublicDataAPI.get_instruments(
   instType="SPOT"
)
print(result)

# %% [markdown]
# ## Make sure you have enough funds to trade a certain pair. Please refer to [Get maximum tradable amount](https://www.okx.com/docs-v5/en/#rest-api-account-get-maximum-available-tradable-amount)

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_max_avail_size(
    instId="BTC-USDT",
    tdMode="cash"
)
print(result)

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_max_avail_size(
    instId="BTC-USDT",
    tdMode="cash"
)
print(result)

# %% [markdown]
# ## In unified account, you can trade Spot under simple, single currency, multi currency and portfolio margin account mode. Please refer to [Introduction on Unified Account](https://www.okx.com/support/hc/en-us/articles/360054690791-1-统一交易账户介绍)

# %% [markdown]
# ## Get the current account configuration from the `acctLv` parameter in [Get account configuration](https://www.okx.com/docs-v5/en/#rest-api-account-get-account-configuration).

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)
result = accountAPI.get_account_config()
print(result)

if result['code'] == "0":
    acctLv = result["data"][0]["acctLv"]
    if acctLv == "1":
        print("Simple mode")
    elif acctLv == "2":
        print("Single-currency margin mode")
    elif acctLv == "3":
        print("Multi-currency margin mode")
    elif acctLv == "4":
        print("Portfolio margin mode")

# %% [markdown]
# # Start Spot Trading

# %% [markdown]
# ### Spot trading under simple/single-currency margin mode

# %%
import okx.Trade as Trade

flag = "1"  # live trading: 0, demo trading: 1

tradeAPI = Trade.TradeAPI(api_key, secret_key, passphrase, False, flag)

# %% [markdown]
# #### place a limit order

# %%
# limit order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="limit",
    px="19000",
    sz="0.01"
)
print(result)

if result["code"] == "0":
    print("Successful order request，order_id = ",result["data"][0]["ordId"])
else:
    print("Unsuccessful order request，error_code = ",result["data"][0]["sCode"], ", Error_message = ", result["data"][0]["sMsg"])

# %% [markdown]
# #### place a market order

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
)
print(result)

# %% [markdown]
# #### place an order with tgtCcy=quote_ccy (only applicable to spot)

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
    tgtCcy="quote_ccy" # this determines the unit of the sz parameter. base_ccy is the default value
)
print(result)

# %% [markdown]
# #### place an order with your own clOrdId

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
    clOrdId="003" # you can define your own client defined order ID
)
print(result)

# %% [markdown]
# ### Spot trading under multi-currency/porfolio margin mode

# %%
# cross-margin spot trading
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cross",
    side="buy",
    ordType="limit",
    px="1000",
    sz="0.01"
)
print(result)

if result["code"] == "0":
    print("Successful order request，order_id = ",result["data"][0]["ordId"])
else:
    print("Unsuccessful order request，error_code = ",result["data"][0]["sCode"], ", Error_message = ", result["data"][0]["sMsg"])

# %% [markdown]
# ### For additional information on the place order endpoint，please refer to [Place order](https://www.okx.com/docs-v5/en/#rest-api-trade-place-order)
#
# ### To place orders in a batch, please refer to [Get account configuration](https://www.okx.com/docs-v5/en/#rest-api-trade-place-multiple-orders)

# %%
place_orders = [
    {"instId":"BTC-USDT", "tdMode":"cash", "side":"buy", "ordType" : "limit","px":"1000","sz":"0.01"},
    {"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "limit", "px": "1000", "sz": "0.02"}
]

result = tradeAPI.place_multiple_orders(place_orders)
print(result)

# %% [markdown]
# ### To amend pending orders，please refer to [Amend order](https://www.okx.com/docs-v5/en/#rest-api-trade-amend-order)

# %%
result = tradeAPI.amend_order(
    instId="BTC-USDT",
    ordId="489103565508685824",
    newSz="0.012"
)
print(result)

# %% [markdown]
# ### To amend orders in a batch, please refer to [Amend multiple orders](https://www.okx.com/docs-v5/en/#rest-api-trade-amend-multiple-orders)

# %%
amend_orders = [
    {"instId": "BTC-USDT", "ordId": "489106394289909760","newSz":"0.001"},
    {"instId": "BTC-USDT", "ordId": "489106394289909761","newSz":"0.001"},
]

result = tradeAPI.amend_multiple_orders(amend_orders)
print(result)

# %% [markdown]
# ### To cancel pending orders，please refer to [Cancel order](https://www.okx.com/docs-v5/en/#rest-api-trade-cancel-order)

# %%
result = tradeAPI.cancel_order(instId="BTC-USDT", ordId = "489093931993509888")
print(result)

# %% [markdown]
# ### To cancel orders in a batch，please refer to [Cancel multiple orders](https://www.okx.com/docs-v5/zh/#rest-api-trade-cancel-multiple-orders)

# %%
cancel_orders = [
    {"instId": "BTC-USDT", "ordId": "489102222534488064"},
    {"instId": "BTC-USDT", "ordId": "489102222534488065"},
]

result = tradeAPI.cancel_multiple_orders(cancel_orders)
print(result)

# %% [markdown]
# ## Get details of a certain order, please refer to [Get order details](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-details)

# %%
result = tradeAPI.get_order(instId="BTC-USDT", clOrdId="002")
print(result)

# %%
result = tradeAPI.get_order(instId="BTC-USDT", ordId="497819823594909696")
print(result)

# %% [markdown]
# ## To get the list of open orders，please refer to [Get order List](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-list)

# %%
result = tradeAPI.get_order_list()
print(result)

# %% [markdown]
# ### To get past orders，please refer to [Get order history (last 7 days）](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-history-last-7-days) and [Get order history (last 3 months)](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-history-last-3-months)

# %%
result = tradeAPI.get_orders_history(
    instType="SPOT"
)
print(result)

# %%
result = tradeAPI.get_orders_history_archive(
    instType="SPOT"
)
print(result)

# %% [markdown]
# ### To get past trades，please refer to [Get transaction details (last 3 days）](https://www.okx.com/docs-v5/en/#rest-api-trade-get-transaction-details-last-3-days) and [Get transaction details (last 3 months) ](https://www.okx.com/docs-v5/en/#rest-api-trade-get-transaction-details-last-3-months)

# %%
result = tradeAPI.get_fills(
    instType="SPOT"
)
print(result)

# %%
result = tradeAPI.get_fills_history(
    instType="SPOT"
)
print(result)

# %% [markdown]
# ### If you wish to place orders when the price reaches a certain level, you can place an algo order

# %%
result = tradeAPI.place_algo_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",             # buy
    ordType="trigger",      # order type
    sz="100",               # order amount: 100USDT
    triggerPx="10000",      # trigger price
    orderPx="-1",           # order price. When orderPx=-1, the order will be placed as an market order
    triggerPxType="last"    # trigger price type。last：last trade price
)
print(result)

# %% [markdown]
# ## You can also use Stop Loss or Take Profit order to sell the currencies in your account

# %%
result = tradeAPI.place_algo_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="sell",                # sell
    ordType="conditional",      # one-way take profit or stop loss
    sz="0.01",               # order amount: 0.01BTC
    tpTriggerPx="30000",      # take profit trigger price
    tpOrdPx="-1",           # taker profit order price。When it is set to -1，the order will be placed as an market order
    tpTriggerPxType="last"    # take profit trigger price type。last：last trade price
)
print(result)

# %% [markdown]
# ### For additional information, please refer to  [Place algo order](https://www.okx.com/docs-v5/en/#rest-api-trade-place-algo-order)

# %% [markdown]
# ### Cancel pending algo orders (not including Iceberg order, TWAP order, Trailing Stop order)，please refer to [Cancel algo order](https://www.okx.com/docs-v5/en/#rest-api-trade-cancel-algo-order)

# %%
algo_orders = [
    {"instId": "BTC-USDT", "algoId": "495001187587043328"},
]

result = tradeAPI.cancel_algo_order(algo_orders)
print(result)

# %% [markdown]
# ### To get list of currently pending algo orders，please refer to [Get algo order list](https://www.okx.com/docs-v5/en/#rest-api-trade-get-algo-order-list)

# %%
result = tradeAPI.order_algos_list(
    ordType="trigger"     # order type
)
print(result)

# %% [markdown]
# ### To get the past algo orders (last three months)，please refer to [Get algo order history](https://www.okx.com/docs-v5/en/#rest-api-trade-get-algo-order-history)

# %%
result = tradeAPI.order_algos_history(
    ordType="conditional",     # order type
    state="canceled"           # state of the orders
)
print(result)
